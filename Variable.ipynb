# %%
# import general librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'Name': ['TARGET', 'AMT_DRAWINGS', 'AMT_TOTAL_RECEIVABLE','AMT_CREDIT_LIMIT_ACTUAL',
                'AMT_BALANCE','CREDIT_DAY_OVERDUE','DAYS_CREDIT_ENDDATE','AMT_REQ_CREDIT_BUREAU_YEAR','SK_DPD_DEF',
                'CNT_INSTALMENT_FUTURE','CREDIT_DAY_OVERDUE','DAYS_CREDIT_ENDDATE','Nombre_active',
                 'NAME_CONTRACT_STATUS_Refused','NAME_CONTRACT_STATUS_Approved','DAYS_REGISTRATION','Age',
                 'REGION_POPULATION_RELATIVE','NAME_HOUSING_TYPE','NAME_INCOME_TYPE','NAME_FAMILY_STATUS',
                 'PAYMENT_RATE','YEAR_EMPLOYED_PERCENT','CREDIT_TO_GOODS_RATIO','CREDIT_LENGTH','CREDIT_INCOME',
                 'ANNUITY_INCOME','FLAG_OWN_REALTY','FLAG_OWN_CAR','CODE_GENDER','NAME_CONTRACT_TYPE','PAYMENT_RATE',
                'CREDIT_TO_GOODS_RATIO','YEAR_EMPLOYED_PERCENT','CREDIT_LENGTH','CREDIT_INCOME','REJECT_REASON',
                'NAME_CONTRACT_STATUS_Refused','NAME_CONTRACT_STATUS_Canceled','NAME_CONTRACT_STATUS_Approved','AMT_DOWN_PAYMENT',
                'AMT_CREDIT_y','Diff_day','SK_DPD_DEF','CNT_INSTALMENT_FUTURE','Status_active','Comsumer_type_crd',
                'AMT_CREDIT_SUM','EXT_SOURCE_1'],
        
        
        
        'Definition': ['Etiquette 0 ou 1', 'Moyenne du montant du prélèvement par carte crédit',
        ' Moyenne du TOTAL DU MONTANT RECEVABLE',
        'Moyenne de la Limite de la carte de crédit pendant le mois du crédit précédent',
        'Moyenne Solde au cours du mois du crédit',
        'Nombre de jours en retard de paiement','Nombre de jours qui reste pour la fin du crédit',
        'Nombre de demandes de renseignements au Bureau de crédit concernant le client',
        'DPD (jours de retard) au cours du mois du crédit précédent',
        'Nombre année qui reste pour le paiement crédit',
        'Nombre de jours retard de paiement','Nombre de jours qui reste carte crédit',
        'Nombre de crédit en cours dans d\'autres agences ou banques','Nombre de crédit refusé','Nombre de crédit approuvé',
        'Ancienneté','Age',
        'Région pour assurer l\'achat et la vente après','Type d\'achat','Type de revenu',
        'Situation familiale','Taux de paiement','Nombre d\'année d travaille','Taux d\'apport personnel',
        'Nbr d\'années de remboursement','Taux de REVENU / CRÉDIT','Taux de remboursement par an / revenue',
        'Le client possède des biens','Le client possède une voiture','Genre du client','Le prêt est cash ou renouvelable',
        'Taux d\'interêt','Pourcetage de l\'apport personnel','Nombre d\'année d travaille','Nbr d\'années de remboursement du crédit précédent',
        'Taux de REVENU / CRÉDIT','Nbr XNA reject reason','Nbre de demandes refusées',
        'Nbre de demandes annulées','Nbre de demandes approuvées','Moyenne de Montant de l\'apport personnel sur crédit précédent',
        'Moyenne de Montant du crédit précédent','Moyenne des jours de retard du crédit précédent',
        'Nombre moyen des jours (jours de retard) les dpd avec tolérance','Nombre de jours qui reste pour les crédit',
        'Nombre de crédit active dans notre banque','Nombre de crédit de consommation','Moyenne de la somme de montant des crédits',
        'Score normalisé à partir d\'une source de données externe'
                      ]}  
  
# Create DataFrame  
df = pd.DataFrame(data)

# %%
df
# Out:
#                              Name  \
# 0                          TARGET
# 1                    AMT_DRAWINGS
# 2            AMT_TOTAL_RECEIVABLE
# 3         AMT_CREDIT_LIMIT_ACTUAL
# 4                     AMT_BALANCE
# 5              CREDIT_DAY_OVERDUE
# 6             DAYS_CREDIT_ENDDATE
# 7      AMT_REQ_CREDIT_BUREAU_YEAR
# 8                      SK_DPD_DEF
# 9           CNT_INSTALMENT_FUTURE
# 10             CREDIT_DAY_OVERDUE
# 11            DAYS_CREDIT_ENDDATE
# 12                  Nombre_active
# 13   NAME_CONTRACT_STATUS_Refused
# 14  NAME_CONTRACT_STATUS_Approved
# 15              DAYS_REGISTRATION
# 16                            Age
# 17     REGION_POPULATION_RELATIVE
# 18              NAME_HOUSING_TYPE
# 19               NAME_INCOME_TYPE
# 20             NAME_FAMILY_STATUS
# 21                   PAYMENT_RATE
# 22          YEAR_EMPLOYED_PERCENT
# 23          CREDIT_TO_GOODS_RATIO
# 24                  CREDIT_LENGTH
# 25                  CREDIT_INCOME
# ...

# %%
df1=df.sort_values(by=['Name'])
df1
# Out:
#                              Name  \
# 4                     AMT_BALANCE
# 3         AMT_CREDIT_LIMIT_ACTUAL
# 47                 AMT_CREDIT_SUM
# 41                   AMT_CREDIT_y
# 40               AMT_DOWN_PAYMENT
# 1                    AMT_DRAWINGS
# 7      AMT_REQ_CREDIT_BUREAU_YEAR
# 2            AMT_TOTAL_RECEIVABLE
# 26                 ANNUITY_INCOME
# 16                            Age
# 44          CNT_INSTALMENT_FUTURE
# 9           CNT_INSTALMENT_FUTURE
# 29                    CODE_GENDER
# 5              CREDIT_DAY_OVERDUE
# 10             CREDIT_DAY_OVERDUE
# 35                  CREDIT_INCOME
# 25                  CREDIT_INCOME
# 34                  CREDIT_LENGTH
# 24                  CREDIT_LENGTH
# 32          CREDIT_TO_GOODS_RATIO
# 23          CREDIT_TO_GOODS_RATIO
# 46              Comsumer_type_crd
# 11            DAYS_CREDIT_ENDDATE
# 6             DAYS_CREDIT_ENDDATE
# 15              DAYS_REGISTRATION
# 42                       Diff_day
# ...

# %%
# Save in CSV format
df1.to_csv('Downloads/Variable.csv',index=False)
